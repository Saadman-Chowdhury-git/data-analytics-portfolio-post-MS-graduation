# %%
import sys
import os
import platform
import site

print("---- Python Environment Check ----")

print("Python version:")
print(sys.version)

print("\nPython executable:")
print(sys.executable)

print("\nVirtual environment prefix:")
print(sys.prefix)

print("\nBase prefix (system Python):")
print(sys.base_prefix)

print("\nPlatform:")
print(platform.platform())

print("\nSite-packages locations:")
for p in site.getsitepackages():
    print(p)

print("\nEnvironment variable VIRTUAL_ENV:")
print(os.environ.get("VIRTUAL_ENV"))

print("\n----------------------------------")
# Out:
# ---- Python Environment Check ----
# Python version:
# 3.14.2 (main, Dec  5 2025, 16:49:16) [Clang 17.0.0 (clang-1700.4.4.1)]
#
# Python executable:
# /Users/saadmanchowdhury/Desktop/All Github projects/.venv/bin/python
#
# Virtual environment prefix:
# /Users/saadmanchowdhury/Desktop/All Github projects/.venv
#
# Base prefix (system Python):
# /opt/homebrew/opt/python@3.14/Frameworks/Python.framework/Versions/3.14
#
# Platform:
# macOS-15.6-arm64-arm-64bit-Mach-O
#
# Site-packages locations:
# /Users/saadmanchowdhury/Desktop/All Github projects/.venv/lib/python3.14/site-packages
#
# Environment variable VIRTUAL_ENV:
# /Users/saadmanchowdhury/Desktop/All Github projects/.venv
#
# ----------------------------------
