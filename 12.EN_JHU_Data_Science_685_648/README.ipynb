# %% [markdown]
# # EN.685.648 Environment / Workflow Notes
#
# ## Project location
#
# This class folder is located inside my main projects folder:
#
# `/Users/saadmanchowdhury/Desktop/All Github projects/12.EN_JHU_Data_Science_685_648`
#
# This folder is part of the parent Git repository:
#
# `/Users/saadmanchowdhury/Desktop/All Github projects`
#
# So I should **not** run `git init` inside the class folder.
#
# ---
#
# ## Conda environment
#
# The class Conda environment is:
#
# `en685648`
#
# It was created from:
#
# `environment.yml`
#
# The environment uses:
#
# - Python 3.11
# - DuckDB 0.9.2
# - pandas, scikit-learn, statsmodels, Jupyter, and related class packages
#
# I only need to create the environment once. I do **not** need to recreate it every time.
#
# ---
#
# ## Notebook workflow
#
# For Jupyter notebooks in VS Code, I should check the top-right kernel.
#
# The correct kernel is:
#
# `en685648 Python 3.11.15`
#
# If the notebook is using this kernel, I do **not** need to activate Conda in the terminal just to run notebook cells.
#
# ---
#
# ## Terminal workflow
#
# If I use the VS Code Terminal or Mac Terminal to run Python commands for this class, I should activate the class environment first:
#
# ```bash
# conda activate en685648

# %%
import sys
import duckdb
import pandas as pd
import sklearn
import statsmodels

print(sys.executable)
print(sys.version)
print("duckdb:", duckdb.__version__)
print("pandas:", pd.__version__)
print("sklearn:", sklearn.__version__)
print("statsmodels:", statsmodels.__version__)
# Out:
# /opt/miniconda3/envs/en685648/bin/python
# 3.11.15 | packaged by conda-forge | (main, Mar  5 2026, 16:59:26) [Clang 19.1.7 ]
# duckdb: 0.9.2
# pandas: 3.0.3
# sklearn: 1.8.0
# statsmodels: 0.14.6
